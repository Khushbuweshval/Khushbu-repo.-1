# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushbuweshval/Khushbu-repo.-1/blob/main/assignment01_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# What is the result of the following expression
#
# 5+3*2

# %%
num=[5+3*2]
print(sum(num))
# Out:
# 11

# %% [markdown]
# What is the output of the following cord.
#
# x=5
#
# y=10
#
# x +=y
#
# print(x)

# %%
x=5
y=10
x+=y

print(x)
# Out:
# 15

# %% [markdown]
# Evluate the following boolean expression.
#
# (10>5)and (not(5>10))

# %%
if 10>5:
  print('10 is grater then 5')
# Out:
# 10 is grater then 5

# %% [markdown]
# What is the result of the following division.
#
# 7/2

# %%
7/2
print(7/2)
# Out:
# 3.5

# %% [markdown]
# What will be the value and types of 'x' after the following operation?
#
# x = 4//2

# %%
x=4//2
print("x",4//2)
# Out:
# x 2

# %% [markdown]
# What is the output of the following cord?
#
# a=[1,2,3]
#
# b=a
#
# b[0]=4
#
# print(a)

# %%
from re import A
a=[1,2,3]
b=a
b[0]=4
print(b)
print(a)
# Out:
# [4, 2, 3]
# [4, 2, 3]

# %% [markdown]
# What does the following slice operation return?
#
# s="hello"
#
# print(s[1:4])

# %%
s="hello"
print(s[1:4])
# Out:
# ell

# %% [markdown]
# What will be the value of 'result'?
#
# result=2**3**2

# %%
result=2**3**2
print(result)
# Out:
# 512

# %% [markdown]
# Given the list'a=[1,2,3,4,5]',what will be the result of 'a[::-1]'?

# %%
a=[1,2,3,4,5]
a[::-1]
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# Evaluate the following expression:
#
# 10%3

# %%
print(10%3)
# Out:
# 1

# %%
what is the result of the follewing cord?
x=[1,2,3]
y=[1,2,3]
print(x == y)
print(x is y)
# Out:
# Object `cord` not found.
# True
# False

# %% [markdown]
# What is the output of the following cord?

# %%
x="python"
y=x*3
print(y)
# Out:
# pythonpythonpython

# %% [markdown]
# What is the type and value of 'x'after the following operation ?
#
# x=true+1

# %%
x=True+1
print(x)
type(x)
# Out:
# 2
# int

# %% [markdown]
# What will be the output of the following comparison?
#
# print("abc"<"abd")

# %%
print('abc'<'abd')
# Out:
# True

# %% [markdown]
# What is the result of the following code?
#
# d={"a":1,"b":2)
#
# d['c']=3
#
# print(d)

# %%
d={'a':1,'b':2}
d['c']=3
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# What will be the value of 'a' after the following operation?
#
# a="123"
#
# a+="456"

# %%
a="123"
a+="456"
print(a)
type(a)
# Out:
# 123456
# str

# %% [markdown]
# What is the output of the following cord?
#
# a=[1,2,3]
# b=a[:]
# b.append(4)
# print(a)
# print(b)

# %%
a=[1,2,3]
b=a[:]
b.append(4)
print(a)
print(b)
# Out:
# [1, 2, 3]
# [1, 2, 3, 4]

# %% [markdown]
# Evaluate the following expression:
#
# 3*(2+4)**2

# %%
3*(2+4)**2
# Out:
# 108

# %% [markdown]
# What will be the result of the following comparison?
#
# print(5==5.0)

# %%
print(5==5.0)
# Out:
# True

# %% [markdown]
# What is the output of the following cord?
#
# x=(1,2,3)
#
# y=x+(4,)
#
# print(y)

# %%
x=(1,2,3)
y=x+(4,)
print(y)
# Out:
# (1, 2, 3, 4)
