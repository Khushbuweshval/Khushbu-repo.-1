# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushbuweshval/Khushbu-repo.-1/blob/main/1_concatination_boolean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# we are learning different data type in python.

# %%
#comments -- comments are not the part of the executable cord , they are added only increase the readablitly

# %% [markdown]
# ways in which we can execute the coed call
# ctrl.+Enter
#
# 1.  shift+Enter
# 2.  ctrl. +Enter
# 3. play the play button

# %%
A=155

# %%
print (A)
# Out:
# 155

# %%
type (A)
# Out:
# int

# %%
b=-8.9

# %%
print (b)
# Out:
# -8.9

# %%
type (b)
# Out:
# float

# %%
c=4-2j

# %%
print(c)
# Out:
# (4-2j)

# %%
type(c)
# Out:
# complex

# %% [markdown]
# MY EXAMPLES

# %%
Z=50

# %%
type(Z)
# Out:
# int

# %%
print(Z)
# Out:
# 50

# %%
q=1995-4j

# %%
type(q)
# Out:
# complex

# %%
print(q)
# Out:
# (1995-4j)

# %%
n=1234-1233j

# %%
print(n)
# Out:
# (1234-1233j)

# %%
type(n)
# Out:
# complex

# %%
a=5.6

# %%
print(a)
# Out:
# 5.6

# %%
type(a)
# Out:
# float

# %%
nisha=29.4

# %%
print(nisha)
# Out:
# 29.4

# %%
type(nisha)
# Out:
# float

# %%
nisha=29-95j

# %%
print(nisha)
# Out:
# (29-95j)

# %%
type(nisha)
# Out:
# complex

# %%
d="indion ocean"

# %%
print(d)
# Out:
# indion ocean

# %%
type(d)
# Out:
# str

# %%
name="Ashutosh"

# %%
type(name)
# Out:
# str

# %%
print(name)
# Out:
# Ashutosh

# %%
num="-4.895"

# %%
type(num)
# Out:
# str

# %%
print(num)
# Out:
# -4.895

# %%
My_list=['Apple','Russia','Mango','India',45,52,-4.5,-3.8]

# %%
print(My_list)
# Out:
# ['Apple', 'Russia', 'Mango', 'India', 45, 52, -4.5, -3.8]

# %%
type(My_list)
# Out:
# list

# %%
new_list=[12,9,4,5,2,8,7]

# %%
type(new_list)
# Out:
# list

# %%
print(new_list)
# Out:
# [12, 9, 4, 5, 2, 8, 7]

# %%
akash_list=['mango',22,-2.9]

# %%
print(akash_list)
# Out:
# ['mango', 22, -2.9]

# %%
type(akash_list)
# Out:
# list

# %%
num=[1233,"prateek"]

# %%
type(num)
# Out:
# list

# %%
print(num)
# Out:
# [1233, 'prateek']

# %%
t=('Apple','Russia','Mango',45,52,-4.5,-3.8)

# %%
type(t)
# Out:
# tuple

# %%
print(t)
# Out:
# ('Apple', 'Russia', 'Mango', 45, 52, -4.5, -3.8)

# %% [markdown]
# opretions in string and list
#  1. concatination
#  2. Indexing
#  3. slicing

# %%
#concatination in string

# %%
a="My"

# %%
b="desketop"

# %%
print(a+b)
# Out:
# Mydesketop

# %%
print(a+' '+b)
# Out:
# My desketop

# %%
first_name ="Aashutosh"
middil_name ="kumar"
last_name="mishra"

# %%
print("your full name is",first_name+' '+middil_name+' '+last_name)
# Out:
# your full name is Aashutosh kumar mishra

# %%
#concatination in list
L1=[1,2,3,4,5,6]
L2=["Mango","Apple"]
print(L1+L2)
# Out:
# [1, 2, 3, 4, 5, 6, 'Mango', 'Apple']

# %%
first_name= "Khushbu"
middil_name="mohit"
last_name="shrivastav"
print("My nane is",first_name+' '+middil_name+' '+last_name)
# Out:
# My nane is Khushbu mohit shrivastav

# %%
#indexing in string

# %%
word='Indion ocean'

# %%
word[9]
# Out:
# 'e'

# %%
word[-1]
# Out:
# 'n'

# %%
word[2]
# Out:
# 'd'

# %%
word[-1]
# Out:
# 'n'

# %%
#indexing in list

# %%
l_new=['AI','Data scientist','Mango','pineapple','python','pySpark',5,7,9,10]

# %%
l_new[2]
# Out:
# 'Mango'

# %%
l_new[-8]
# Out:
# 'Mango'

# %%
l_new[5]
# Out:
# 'pySpark'

# %%
l_new[-5]
# Out:
# 'pySpark'

# %%
l_new[8]
# Out:
# 9

# %%
l_new[-2]
# Out:
# 9

# %%
l_new[3]
# Out:
# 'pineapple'

# %%
l_new[-7]
# Out:
# 'pineapple'

# %%
#fatching 'a' from mango
khushbu=l_new[2]

# %%
khushbu
# Out:
# 'Mango'

# %%
khushbu[1]
# Out:
# 'a'

# %%
#concatination in indexing
first_name='pratiksha'
middil_name='Vishvas'
print(first_name+" "+middil_name)
# Out:
# pratiksha Vishvas

# %%
name=first_name+" "+middil_name

# %%
name[10]
# Out:
# 'V'

# %%
name[-7]
# Out:
# 'V'

# %%
#slicing in string
a="United nations"

# %%
a[0:6]
# Out:
# 'United'

# %%
a[-14:-8]
# Out:
# 'United'

# %%
a[7:]
# Out:
# 'nations'

# %%
a[-7:]
# Out:
# 'nations'

# %%
a[3:13]
# Out:
# 'ted nation'

# %%
a[-11:-1]
# Out:
# 'ted nation'

# %%
#slicing in list
My_list=[1,2,3,'Russia','USA','Alaska','Israel',5,8,-4.9]

# %%
My_list[4:7]
# Out:
# ['USA', 'Alaska', 'Israel']

# %%
My_list[-6:-3]
# Out:
# ['USA', 'Alaska', 'Israel']

# %%
#builting funtion with the rispecte string and list

# %%
a='aashutosh'

# %%
print(a.upper())
# Out:
# AASHUTOSH

# %%
b=a.upper()

# %%
print(b)
# Out:
# AASHUTOSH

# %%
print(b.lower())
# Out:
# aashutosh

# %%
name='aAshutosh'

# %%
print(name.capitalize())
# Out:
# Aashutosh

# %%
print(len(name))
# Out:
# 9

# %%
print(name.count("s"))
# Out:
# 2

# %%
print(name.count("A"))
# Out:
# 1

# %%
statment= 'Hello I am doing good,I am going to Banglore next weekend,I am going to stay for 8 week'

# %%
print(len(statment))
# Out:
# 87

# %%
print(statment.replace("I am","we are"))
# Out:
# Hello we are doing good,we are going to Banglore next weekend,we are going to stay for 8 week

# %%
print(statment.replace("I am","we are",1))
# Out:
# Hello we are doing good,I am going to Banglore next weekend,I am going to stay for 8 week

# %%
print(statment.replace("I am","these are"))
# Out:
# Hello these are doing good,these are going to Banglore next weekend,these are going to stay for 8 week

# %%
print(statment.replace("I am","these are",2))
# Out:
# Hello these are doing good,these are going to Banglore next weekend,I am going to stay for 8 week

# %%
print(len(statment))
# Out:
# 87

# %%
My_list=['artificial intellegence','Mechine learning','python','NLp']

# %%
My_list.append('computer vision')

# %%
print(My_list)
# Out:
# ['artificial intellegence', 'Mechine learning', 'python', 'NLp', 'computer vision']

# %%
My_list.append('Statistics')

# %%
print(My_list)
# Out:
# ['Data science', 'data science', 'artificial intellegence', 'Mechine learning', 'computer vision', 'python', 'NLp', 'computer vision', 'Statistics']

# %%
My_list.insert(2,'computer vision')

# %%
print(My_list)
# Out:
# ['artificial intellegence', 'Mechine learning', 'computer vision', 'python', 'NLp', 'computer vision']

# %%
My_list.insert(0,'Data science')

# %%
print(My_list)
# Out:
# ['Data science', 'data science', 'artificial intellegence', 'Mechine learning', 'computer vision', 'python', 'NLp', 'computer vision']

# %%
print(My_list)
# Out:
# ['Data science', 'data science', 'artificial intellegence', 'Mechine learning', 'computer vision', 'python', 'NLp', 'computer vision', 'Statistics']

# %%
My_list.remove('Statistics')

# %%
print(My_list)
# Out:
# ['Data science', 'data science', 'artificial intellegence', 'Mechine learning', 'computer vision', 'python', 'NLp', 'computer vision']

# %%
My_list.remove('data science')

# %%
print(My_list)
# Out:
# ['Data science', 'artificial intellegence', 'Mechine learning', 'computer vision', 'python', 'NLp', 'computer vision']

# %%
My_list.remove('computer vision')

# %%
print(My_list)
# Out:
# ['Data science', 'artificial intellegence', 'Mechine learning', 'python', 'NLp', 'computer vision']

# %%
My_list.pop()
# Out:
# 'computer vision'

# %%
print(My_list)
# Out:
# ['Data science', 'artificial intellegence', 'Mechine learning', 'python', 'NLp']

# %%
My_list.pop(0)
# Out:
# 'Data science'

# %%
print(My_list)
# Out:
# ['artificial intellegence', 'Mechine learning', 'python', 'NLp']

# %%
My_list.pop(0)
# Out:
# 'artificial intellegence'

# %%
print(My_list)
# Out:
# ['Mechine learning', 'python', 'NLp']

# %%
My_list.extend(['Apple',23,'Banana','Mango'])

# %%
print(My_list)
# Out:
# ['Mechine learning', 'python', 'NLp', 'Apple', 23, 'Banana', 'Mango']

# %%
print(len(My_list))
# Out:
# 7

# %%
New_list=[2,3,4,5,9,8,5,3,2,5,7,2,9]

# %%
New_list.sort()

# %%
print(New_list)
# Out:
# [2, 2, 2, 3, 3, 4, 5, 5, 5, 7, 8, 9, 9]

# %%
New_list.sort(reverse=True)

# %%
print(New_list)
# Out:
# [9, 9, 8, 7, 5, 5, 5, 4, 3, 3, 2, 2, 2]

# %%
print(max(New_list))
# Out:
# 9

# %%
print(min(New_list))
# Out:
# 2

# %%
print(sum(New_list))
# Out:
# 64

# %%
print(len(New_list))
# Out:
# 13

# %%
print(New_list.count(2))
# Out:
# 3

# %%
#nested list -- lisi insid an existing list

# %%
l1=["India","USA",["china","Apple","Mango",23,45,-8.9,33]]

# %%
z=l1[0:2]

# %%
print(z)
# Out:
# ['India', 'USA']

# %%
y=l1[2][0]

# %%
print(y)
# Out:
# china

# %%
w=list(y)

# %%
print(w)
# Out:
# ['c', 'h', 'i', 'n', 'a']

# %%
print(z+w)
# Out:
# ['India', 'USA', 'c', 'h', 'i', 'n', 'a']

# %%
a=l1[2][0:2]

# %%
print(a)
# Out:
# ['china', 'Apple']

# %%
b=l1[0]

# %%
print(b)
# Out:
# India

# %%
c=list(b)

# %%
print(c)
# Out:
# ['I', 'n', 'd', 'i', 'a']

# %%
print(a+c)
# Out:
# ['china', 'Apple', 'I', 'n', 'd', 'i', 'a']

# %%
l1[2][0]
# Out:
# 'china'

# %%
l1[-1][-7]
# Out:
# 'china'

# %%
l1[2][2]
# Out:
# 'Mango'

# %%
l1[-1][-5]
# Out:
# 'Mango'

# %%
l1[2][1:5]
# Out:
# ['Apple', 'Mango', 23, 45]

# %%
l1[-1][-6:-2]
# Out:
# ['Apple', 'Mango', 23, 45]

# %%
l1[2][3:6]
# Out:
# [23, 45, -8.9]

# %%
l1[-1][-4:-1]
# Out:
# [23, 45, -8.9]

# %% [markdown]
# TUPAL (unmutable in nature)

# %%
t=('India','USA','Russia','New Delhi',25,900,-3.9,-0.8)

# %%
print(t)
# Out:
# ('India', 'USA', 'Russia', 'New Delhi', 25, 900, -3.9, -0.8)

# %%
type(t)
# Out:
# tuple

# %%
t[-2]
# Out:
# -3.9

# %%
t[6]
# Out:
# -3.9

# %%
t[2]
# Out:
# 'Russia'

# %%
t[-6]
# Out:
# 'Russia'

# %%
t[0]
# Out:
# 'India'

# %%
t[-8]
# Out:
# 'India'

# %%
My_tup=(2,3,4,5,6,7,9)

# %%
sum(My_tup)
# Out:
# 36

# %%
max(My_tup)
# Out:
# 9

# %%
min(My_tup)
# Out:
# 2

# %%
len(My_tup)
# Out:
# 7

# %% [markdown]
# DICTIONARIES

# %%
Memo={'chips':100,'icecream':300,'chocolet':300,'pen':50,'bread':45}

# %%
print(Memo)
# Out:
# {'chips': 100, 'icecream': 300, 'chocolet': 300, 'pen': 50, 'bread': 45}

# %%
type(Memo)
# Out:
# dict

# %%
Memo['pen']
# Out:
# 50

# %%
Memo['chocolet']
# Out:
# 300

# %%
Memo['icecream']=250

# %%
print(Memo)
# Out:
# {'chips': 50, 'icecream': 250, 'chocolet': 300, 'pen': 50, 'bread': 45}

# %%
Memo['chips']=50

# %%
print(Memo)
# Out:
# {'chips': 50, 'icecream': 300, 'chocolet': 300, 'pen': 50, 'bread': 45}

# %%
Memo.keys()
# Out:
# dict_keys(['chips', 'icecream', 'chocolet', 'pen', 'bread'])

# %%
Memo.values()
# Out:
# dict_values([50, 300, 300, 50, 45])

# %%
Memo['Notebook']=90

# %%
print(Memo)
# Out:
# {'chips': 100, 'icecream': 250, 'chocolet': 300, 'pen': 50, 'bread': 45, 'Notebook': 90}

# %%
Memo.popitem()
# Out:
# ('Notebook', 90)

# %%
print(Memo)
# Out:
# {'chips': 100, 'icecream': 250, 'chocolet': 300, 'pen': 50, 'bread': 45}

# %%
Memo.clear()

# %%
print(Memo)
# Out:
# {}

# %%
salary_sheet={'name':'Bob','age':39,'salary':35000,'city':'Newyork'}

# %%
salary_sheet['designation']='software enggniar'

# %%
print(salary_sheet)
# Out:
# {'name': 'Bob', 'age': 39, 'salary': 35000, 'city': 'Newyork', 'designation': 'software enggniar'}

# %%
salary_sheet['salary']
# Out:
# 35000

# %%
salary_sheet['salary']=55000

# %%
print(salary_sheet)
# Out:
# {'name': 'Bob', 'age': 39, 'salary': 55000, 'city': 'Newyork', 'designation': 'software enggniar'}

# %%
del salary_sheet['age']

# %%
print(salary_sheet)
# Out:
# {'name': 'Bob', 'salary': 55000, 'city': 'Newyork', 'designation': 'software enggniar'}

# %% [markdown]
# SATS (they are not in oder)

# %%
school={1,2,3,2,1,'India','Russia'}

# %%
print(school)
# Out:
# {'Russia', 1, 2, 3, 'India'}

# %%
type(school)
# Out:
# set

# %%
school.add(10)

# %%
print(school)
# Out:
# {'Russia', 1, 2, 3, 10, 'India'}

# %%
school.add('Pakistan')

# %%
print(school)
# Out:
# {'Russia', 1, 2, 3, 10, 'India', 'Pakistan'}

# %%
school.discard('Pakistan')

# %%
print(school)
# Out:
# {'Russia', 1, 2, 3, 10, 'India'}

# %% [markdown]
# BOOLEAN

# %%
a=10
b=20
print(a>b)
# Out:
# False

# %%
type(a>b)
# Out:
# bool

# %%
print(a<b)
# Out:
# True

# %%
type(a<b)
# Out:
# bool
